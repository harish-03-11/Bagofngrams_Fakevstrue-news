# %% [markdown]
# <a href="https://colab.research.google.com/github/harish-03-11/Bagofngrams_Fakevstrue-news/blob/main/Bagof_ngrams_Fakenews_vs_real_news.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("/content/sample_data/True.csv")
df2 = pd.read_csv("/content/sample_data/Fake.csv")

# %%
df1.sample(3)
# Out:
#                                                    title  \
# 2450   Hypothetically speaking, U.S. Admiral says rea...
# 5841   Trump expected to sign cyber security executiv...
# 18332  Russia raps Canada's Magnitsky bill, ready to ...
#
#                                                     text       subject  \
# 2450   MELBOURNE (Reuters) - The U.S. Pacific Fleet c...  politicsNews
# 5841   WASHINGTON (Reuters) - President Donald Trump ...  politicsNews
# 18332  MOSCOW (Reuters) - Russia said it will retalia...     worldnews
#
#                     date
# 2450      July 27, 2017
# 5841   January 30, 2017
# 18332   October 4, 2017

# %%
df1['text'][0]
# Out:
# 'WASHINGTON (Reuters) - The head of a conservative Republican faction in the U.S. Congress, who voted this month for a huge expansion of the national debt to pay for tax cuts, called himself a “fiscal conservative” on Sunday and urged budget restraint in 2018. In keeping with a sharp pivot under way among Republicans, U.S. Representative Mark Meadows, speaking on CBS’ “Face the Nation,” drew a hard line on federal spending, which lawmakers are bracing to do battle over in January. When they return from the holidays on Wednesday, lawmakers will begin trying to pass a federal budget in a fight likely to be linked to other issues, such as immigration policy, even as the November congressional election campaigns approach in which Republicans will seek to keep control of Congress. President Donald Trump and his Republicans want a big budget increase in military spending, while Democrats also want proportional increases for non-defense “discretionary” spending on programs that support educ
# ...

# %%
df1['label'] = 1
df1.sample(5)
# Out:
#                                                    title  \
# 21183  Vietnam protests over Chinese military drill i...
# 4169   Republican vows 'all hands on deck' in Georgia...
# 6277   U.S. makes $500 million grant to climate chang...
# 16679  Venezuela governors sworn in, showing oppositi...
# 10292  Puerto Rico bill expected soon, House Democrat...
#
#                                                     text       subject  \
# 21183  BEIJING/HANOI (Reuters) - China urged Vietnam ...     worldnews
# 4169   WASHINGTON (Reuters) - A political newcomer wh...  politicsNews
# 6277   WASHINGTON (Reuters) - The United States has m...  politicsNews
# 16679  CARACAS (Reuters) - In another setback for Ven...     worldnews
# 10292  WASHINGTON (Reuters) - U.S. House Democratic L...  politicsNews
#
#                     date  label
# 21183   August 31, 2017       1
# 4169     April 18, 2017       1
# 6277   January 17, 2017       1
# 16679  October 23, 2017       1
# ...

# %%
df2['label'] = 0
df2.sample(3)
# Out:
#                                                    title  \
# 4953    WATCH: Rudy Giuliani Begs People To Search Fo...
# 2947    WATCH: Lewis Black Hilariously BURNS Trump An...
# 19289  SOCIALIST Bernie Sanders Asks Trump’s Pick For...
#
#                                                     text    subject  \
# 4953   On Sunday, Rudy Giuliani appeared on Fox News ...       News
# 2947   If Lewis Black really does have a ticket to th...       News
# 19289  Besty Devos is Trump s conservative choice for...  left-news
#
#                    date  label
# 4953    August 21, 2016      0
# 2947   January 19, 2017      0
# 19289      Jan 18, 2017      0

# %%
df_new = pd.concat([df1,df2], axis = 0)
df_new.sample(10)
# Out:
#                                                    title  \
# 10856  CHECKMATE! PUTIN Offers Up Proof Of Trump’s In...
# 20671  Six farmers killed in apparent land dispute in...
# 16767  EU will lose credibility if it tolerates direc...
# 10352  WATCH Rep. Steve King’s Bombshell Answer on Wh...
# 20791  TRANSPORTATION SECRETARY: Unequal Distribution...
# 9375   House Speaker Ryan: Call with Trump was good, ...
# 9666   Jacobs Technology awarded $427 million contrac...
# 2391    Fox’s Shep Smith Has Yet Another EPIC Anti-Tr...
# 16900  OBAMA WARNS: Crackdown On Terrorism In U.S. Wo...
# 8808    Ted Cruz Gets OWNED By His Own Harvard Law Pr...
#
#                                                     text          subject  \
# 10856  Putin just trolled the Democrats Haha!Vladimir...         politics
# 20671  LIMA (Reuters) - Six farmers were shot dead in...        worldnews
# 16767  LONDON (Reuters) - The European Union will los...        worldnews
# ...

# %%
df_new = df_new.drop('date',axis =1)
df_new.sample(2)
# Out:
#                                                    title  \
# 19610  Philippine lawmakers defer decision on appoint...
# 5438    Cleveland Police Union Leader: There’s Blood ...
#
#                                                     text    subject  label
# 19610  MANILA (Reuters) - Philippine lawmakers on Wed...  worldnews      1
# 5438   Three police officers were shot and killed in ...       News      0

# %%
df_new['subject'].value_counts()
# Out:
# subject
# politicsNews       11272
# worldnews          10145
# News                9050
# politics            6841
# left-news           4459
# Government News     1570
# US_News              783
# Middle-east          778
# Name: count, dtype: int64

# %%
df_new['subject'] = df_new.subject.map({'politicsNews': 1,
'worldnews'	: 2,
'News' : 2,
'politics':1,
'left-new':3,
'Government News':4,
'US_News':5,
'Middle-east':6})

# %%
df_new.sample(4)
# Out:
#                                                    title  \
# 9112   SAY WHAT? PROSECUTORS Claim Convicted ISLAMIC ...
# 10593  Hecklers disrupt Trump rally, photographer sho...
# 16447  Driven by fear, Rohingyas keep fleeing Myanmar...
# 13942  Death toll in attack on mosque in Egypt's nort...
#
#                                                     text  subject  label
# 9112   According to The Sun, George W. Bush  successo...      1.0      0
# 10593  WASHINGTON - A Donald Trump rally in Virginia ...      1.0      1
# 16447  SITTWE, Myanmar (Reuters) - The thousands of R...      2.0      1
# 13942  CAIRO (Reuters) - The death toll in a militant...      2.0      1

# %%
df_new = df_new.drop('title',axis = 1)
df_new.head(3)
# Out:
#                                                 text  subject  label
# 0  WASHINGTON (Reuters) - The head of a conservat...      1.0      1
# 1  WASHINGTON (Reuters) - Transgender people will...      1.0      1
# 2  WASHINGTON (Reuters) - The special counsel inv...      1.0      1

# %%
df_new  = df_new.drop('subject',axis= 1)

# %%
df_new.label.value_counts()
# Out:
# label
# 0    23481
# 1    21417
# Name: count, dtype: int64

# %% [markdown]
# # Converting Word to vector with Bag of n grams/bag of words

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(df_new.text,df_new.label,test_size = 0.2, stratify = df_new.label ,random_state=22)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline

# %%
model = Pipeline([
    ('vectorizer', CountVectorizer()),
    ('Multi NB', MultinomialNB())

])

# %%
model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()),
#                 ('Multi NB', MultinomialNB())])

# %%
y_pred = model.predict(X_train)

# %%
print(classification_report(y_pred,y_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     18644
#            1       0.96      0.96      0.96     17274
#
#     accuracy                           0.96     35918
#    macro avg       0.96      0.96      0.96     35918
# weighted avg       0.96      0.96      0.96     35918

# %%
model_3gram = Pipeline([
    ('vectorizer', CountVectorizer(ngram_range = (1,3))),
    ('Multi NB', MultinomialNB())

])

# %%
model_3gram.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer(ngram_range=(1, 3))),
#                 ('Multi NB', MultinomialNB())])

# %%
y3_pred = model_3gram.predict(X_train)

# %%
print(classification_report(y3_pred,y_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     18736
#            1       1.00      1.00      1.00     17182
#
#     accuracy                           1.00     35918
#    macro avg       1.00      1.00      1.00     35918
# weighted avg       1.00      1.00      1.00     35918
